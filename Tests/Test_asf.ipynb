# %%
import asf_search as asf

# %%
dir(asf)
# Out:
# ['AIRSAR',
#  'ALOS',
#  'AMPLITUDE',
#  'AMPLITUDE_GRD',
#  'ASCENDING',
#  'ASFAuthenticationError',
#  'ASFBaselineError',
#  'ASFDownloadError',
#  'ASFError',
#  'ASFProduct',
#  'ASFSearch4xxError',
#  'ASFSearch5xxError',
#  'ASFSearchError',
#  'ASFSearchOptions',
#  'ASFSearchResults',
#  'ASFSearchResults_to_properties_list',
#  'ASFServerError',
#  'ASFSession',
#  'ASFWKTError',
#  'ASF_AUTH_HOST',
#  'ASF_LOGGER',
#  'AUTH_DOMAINS',
#  'AVNIR_2',
#  'BEAMMODE',
#  'BURST',
#  'CMR',
#  'CMRConceptIDError',
#  'CMRError',
#  'CMR_COLLECTIONS_PATH',
#  'CMR_FORMAT_EXT',
#  'CMR_GRANULE_PATH',
#  'CMR_HEALTH_PATH',
#  'CMR_HOST',
#  'CMR_PAGE_SIZE',
#  'COMPLEX',
#  'CSTOKES',
#  'CTIF',
#  'C_SAR',
#  'DEFAULT_PROVIDER',
#  'DEM',
#  'DEM_TIFF',
#  'DESCENDING',
#  'DSN',
#  'DUAL_HH',
#  'DUAL_HV',
#  'DUAL_VH',
#  'DUAL_VV',
#  'EDL_CLIENT_ID',
#  'EDL_HOST',
#  'EH3',
#  'EH4',
#  'EH6',
#  'EL1',
#  'ERS',
#  'ERS1',
#  'ERS2',
#  'EW',
#  'FBD',
#  'FBS',
# ...

# %%
dir(asf.PLATFORM)
# Out:
# ['AIRSAR',
#  'ALOS',
#  'ERS',
#  'ERS1',
#  'ERS2',
#  'JERS',
#  'RADARSAT',
#  'SEASAT',
#  'SENTINEL1',
#  'SENTINEL1A',
#  'SENTINEL1B',
#  'SIRC',
#  'SMAP',
#  'UAVSAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']
